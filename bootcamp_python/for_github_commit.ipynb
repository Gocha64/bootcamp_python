# %%
import os
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
cd '/gdrive/MyDrive/bootcamp_python'
# Out:
# /gdrive/MyDrive/bootcamp_python

# %%
# !git clone https://Gocha64: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@github.com/Gocha64/bootcamp_python.git
# Out:
# Cloning into 'bootcamp_python'...
# ...

# %%
# !git config --global user.email 'wlgns0194@gmail.com'
# !git config --global user.name 'Gocha64'

# %%
# !git add .
# !git commit -m "backup"
# Out:
# [main a4cec1f] backup
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite for_github_commit.ipynb (60%)

# %%
#!git remote add origin https://Gocha64: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@github.com/Gocha64/bootcamp_python.git
# !git push -u origin main
# Out:
# fatal: 'origin' does not appear to be a git repository
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !git add .
# !git commit -m "for backup"
# !git branch -M main
# !git remote add origin https://Gocha64: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@github.com/Gocha64/bootcamp_python.git
# !git push -u origin main
# Out:
# [main f5b33ff] for backup
#  1 file changed, 1 insertion(+), 1 deletion(-)
# To https://github.com/Gocha64/bootcamp_python.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://Gocha64: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@github.com/Gocha64/bootcamp_python.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git pull origin master --allow-unrelated-histories
# Out:
# fatal: Couldn't find remote ref master

# %%
# !git push -u origin main

# %%
# !git remote rm origin

# %%
# !git pull origin master
# Out:
# fatal: Couldn't find remote ref master
